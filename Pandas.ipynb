# %% [markdown]
# ## class 01

# %%
import pandas as pd

# %%
data={
    'first':['Rafe','Arefin', 'Rezwan','Nayem','Al Amin'],
      'last':['Talukder', 'Khan', 'Ahmed', 'Hossain', 'Mia'],
      'email':['ra@gmail.com', 'ak@hotmail.com', 'ra@gmail.com', 'nh@gmail.com', 'am@gmail.com'],
       'profession':['Data Analyst', 'Student', 'Programer','Developer','Data Analyst'],
    'Salary':[45000, 38000, 35000, 75000, 45000],
    'Age':[23, 22, 24, 28, 23],
    'Experience':[3,2,1,5,3],
    'Gender':['M', 'M', 'M', 'M', 'F']
    }
df = pd.DataFrame(data)
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender
# 0      M
# 1      M
# 2      M
# 3      M
# 4      F

# %%
df['first']
# Out:
# 0       Rafe
# 1     Arefin
# 2     Rezwan
# 3      Nayem
# 4    Al Amin
# Name: first, dtype: object

# %%
df.email
# Out:
# 0      ra@gmail.com
# 1    ak@hotmail.com
# 2      ra@gmail.com
# 3      nh@gmail.com
# 4      am@gmail.com
# Name: email, dtype: object

# %%
df[['first', 'last','email']]
# Out:
#      first      last           email
# 0     Rafe  Talukder    ra@gmail.com
# 1   Arefin      Khan  ak@hotmail.com
# 2   Rezwan     Ahmed    ra@gmail.com
# 3    Nayem   Hossain    nh@gmail.com
# 4  Al Amin       Mia    am@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email', 'profession', 'Salary', 'Age', 'Experience',
#        'Gender'],
#       dtype='object')

# %%
df[['first', 'last']]
# Out:
#      first      last
# 0     Rafe  Talukder
# 1   Arefin      Khan
# 2   Rezwan     Ahmed
# 3    Nayem   Hossain
# 4  Al Amin       Mia

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender
# 0      M
# 1      M
# 2      M
# 3      M
# 4      F

# %%
df.iloc[0]
# Out:
# first                 Rafe
# last              Talukder
# email         ra@gmail.com
# profession    Data Analyst
# Salary               45000
# Age                     23
# Experience               3
# Gender                   M
# Name: 0, dtype: object

# %%
df.iloc[[0,2,4]]
# Out:
#      first      last         email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder  ra@gmail.com  Data Analyst   45000   23           3
# 2   Rezwan     Ahmed  ra@gmail.com     Programer   35000   24           1
# 4  Al Amin       Mia  am@gmail.com  Data Analyst   45000   23           3
#
#   Gender
# 0      M
# 2      M
# 4      F

# %%
df.iloc[3,2]
# Out:
# 'nh@gmail.com'

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender
# 0      M
# 1      M
# 2      M
# 3      M
# 4      F

# %%
df.loc[[0,2,4],['last', 'email']]
# Out:
#        last         email
# 0  Talukder  ra@gmail.com
# 2     Ahmed  ra@gmail.com
# 4       Mia  am@gmail.com

# %%
df['email']
# Out:
# 0      ra@gmail.com
# 1    ak@hotmail.com
# 2      ra@gmail.com
# 3      nh@gmail.com
# 4      am@gmail.com
# Name: email, dtype: object

# %%
df.loc[[0,2,4],['first','last']]
# Out:
#      first      last
# 0     Rafe  Talukder
# 2   Rezwan     Ahmed
# 4  Al Amin       Mia

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender
# 0      M
# 1      M
# 2      M
# 3      M
# 4      F

# %%
df.iloc[3,2]
# Out:
# 'nh@gmail.com'

# %%
df.loc[[2,3],['first', 'last', 'email']]
# Out:
#     first     last         email
# 2  Rezwan    Ahmed  ra@gmail.com
# 3   Nayem  Hossain  nh@gmail.com

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender
# 0      M
# 1      M
# 2      M
# 3      M
# 4      F

# %%
df.iloc[2,1]='Ahmed'

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender
# 0      M
# 1      M
# 2      M
# 3      M
# 4      F

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender
# 0      M
# 1      M
# 2      M
# 3      M
# 4      F

# %%
df.loc[[0],['first', 'last', 'email']]
# Out:
#   first      last         email
# 0  Rafe  Talukder  ra@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email', 'profession', 'Salary', 'Age', 'Experience',
#        'Gender'],
#       dtype='object')

# %%
A=list(df.columns)

# %%
A
# Out:
# ['first',
#  'last',
#  'email',
#  'profession',
#  'Salary',
#  'Age',
#  'Experience',
#  'Gender']

# %%
A.index('email')
# Out:
# 2

# %%
df.columns
# Out:
# Index(['first', 'last', 'email', 'profession', 'Salary', 'Age', 'Experience',
#        'Gender'],
#       dtype='object')

# %%
A=list(df.columns)

# %%
A
# Out:
# ['first',
#  'last',
#  'email',
#  'profession',
#  'Salary',
#  'Age',
#  'Experience',
#  'Gender']

# %%
A.index('first')
# Out:
# 0

# %%
df.columns
# Out:
# Index(['first', 'last', 'email', 'profession', 'Salary', 'Age', 'Experience',
#        'Gender'],
#       dtype='object')

# %%
A=list(df.columns)

# %%
A
# Out:
# ['first',
#  'last',
#  'email',
#  'profession',
#  'Salary',
#  'Age',
#  'Experience',
#  'Gender']

# %%
A.index('email')
# Out:
# 2

# %%
df.columns
# Out:
# Index(['first', 'last', 'email', 'profession', 'Salary', 'Age', 'Experience',
#        'Gender'],
#       dtype='object')

# %%
A=list(df.columns)

# %%
A
# Out:
# ['first',
#  'last',
#  'email',
#  'profession',
#  'Salary',
#  'Age',
#  'Experience',
#  'Gender']

# %%
A.index('last')
# Out:
# 1

# %%
full_name=df['first'] +" "+ df['last']

# %%
full_name
# Out:
# 0    Rafe Talukder
# 1      Arefin Khan
# 2     Rezwan Ahmed
# 3    Nayem Hossain
# 4      Al Amin Mia
# dtype: object

# %%
df['full_name']=full_name

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender      full_name
# 0      M  Rafe Talukder
# 1      M    Arefin Khan
# 2      M   Rezwan Ahmed
# 3      M  Nayem Hossain
# 4      F    Al Amin Mia

# %%
df.insert(2, 'full_name2','full_name')

# %%
df
# Out:
#      first      last full_name2           email    profession  Salary  Age  \
# 0     Rafe  Talukder  full_name    ra@gmail.com  Data Analyst   45000   23
# 1   Arefin      Khan  full_name  ak@hotmail.com       Student   38000   22
# 2   Rezwan     Ahmed  full_name    ra@gmail.com     Programer   35000   24
# 3    Nayem   Hossain  full_name    nh@gmail.com     Developer   75000   28
# 4  Al Amin       Mia  full_name    am@gmail.com  Data Analyst   45000   23
#
#    Experience Gender      full_name
# 0           3      M  Rafe Talukder
# 1           2      M    Arefin Khan
# 2           1      M   Rezwan Ahmed
# 3           5      M  Nayem Hossain
# 4           3      F    Al Amin Mia

# %%
 df.drop(['full_name2'], axis=1,inplace=True)

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender      full_name
# 0      M  Rafe Talukder
# 1      M    Arefin Khan
# 2      M   Rezwan Ahmed
# 3      M  Nayem Hossain
# 4      F    Al Amin Mia

# %%
column_names=['first_name','last_name', 'full_name', 'email',]

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender      full_name
# 0      M  Rafe Talukder
# 1      M    Arefin Khan
# 2      M   Rezwan Ahmed
# 3      M  Nayem Hossain
# 4      F    Al Amin Mia

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender      full_name
# 0      M  Rafe Talukder
# 1      M    Arefin Khan
# 2      M   Rezwan Ahmed
# 3      M  Nayem Hossain
# 4      F    Al Amin Mia

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender      full_name
# 0      M  Rafe Talukder
# 1      M    Arefin Khan
# 2      M   Rezwan Ahmed
# 3      M  Nayem Hossain
# 4      F    Al Amin Mia

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender      full_name
# 0      M  Rafe Talukder
# 1      M    Arefin Khan
# 2      M   Rezwan Ahmed
# 3      M  Nayem Hossain
# 4      F    Al Amin Mia

# %%
df['country']=['Bangladesh', 'China', 'India', 'USA', 'Germany']

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
full_name=df['first'] +" "+ df['last']

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
df['full_name']=full_name

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
df
# Out:
#      first      last           email    profession  Salary  Age  Experience  \
# 0     Rafe  Talukder    ra@gmail.com  Data Analyst   45000   23           3
# 1   Arefin      Khan  ak@hotmail.com       Student   38000   22           2
# 2   Rezwan     Ahmed    ra@gmail.com     Programer   35000   24           1
# 3    Nayem   Hossain    nh@gmail.com     Developer   75000   28           5
# 4  Al Amin       Mia    am@gmail.com  Data Analyst   45000   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
titles=list(df.columns)
titles
# Out:
# ['first',
#  'last',
#  'email',
#  'profession',
#  'Salary',
#  'Age',
#  'Experience',
#  'Gender',
#  'full_name',
#  'country']

# %%
titles [2], titles[3]=titles[3],titles[2]
titles
# Out:
# ['first',
#  'last',
#  'profession',
#  'email',
#  'Salary',
#  'Age',
#  'Experience',
#  'Gender',
#  'full_name',
#  'country']

# %%
df=df[titles]
df
# Out:
#      first      last    profession           email  Salary  Age  Experience  \
# 0     Rafe  Talukder  Data Analyst    ra@gmail.com   45000   23           3
# 1   Arefin      Khan       Student  ak@hotmail.com   38000   22           2
# 2   Rezwan     Ahmed     Programer    ra@gmail.com   35000   24           1
# 3    Nayem   Hossain     Developer    nh@gmail.com   75000   28           5
# 4  Al Amin       Mia  Data Analyst    am@gmail.com   45000   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
df
# Out:
#      first      last    profession           email  Salary  Age  Experience  \
# 0     Rafe  Talukder  Data Analyst    ra@gmail.com   45000   23           3
# 1   Arefin      Khan       Student  ak@hotmail.com   38000   22           2
# 2   Rezwan     Ahmed     Programer    ra@gmail.com   35000   24           1
# 3    Nayem   Hossain     Developer    nh@gmail.com   75000   28           5
# 4  Al Amin       Mia  Data Analyst    am@gmail.com   45000   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
titles=list(df.columns)
titles
# Out:
# ['first',
#  'last',
#  'profession',
#  'email',
#  'Salary',
#  'Age',
#  'Experience',
#  'Gender',
#  'full_name',
#  'country']

# %%
titles[3], titles[4]=titles[4],titles[3]
titles
# Out:
# ['first',
#  'last',
#  'profession',
#  'Salary',
#  'email',
#  'Age',
#  'Experience',
#  'Gender',
#  'full_name',
#  'country']

# %%
df=df[titles]
df
# Out:
#      first      last    profession  Salary           email  Age  Experience  \
# 0     Rafe  Talukder  Data Analyst   45000    ra@gmail.com   23           3
# 1   Arefin      Khan       Student   38000  ak@hotmail.com   22           2
# 2   Rezwan     Ahmed     Programer   35000    ra@gmail.com   24           1
# 3    Nayem   Hossain     Developer   75000    nh@gmail.com   28           5
# 4  Al Amin       Mia  Data Analyst   45000    am@gmail.com   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
df
# Out:
#      first      last    profession  Salary           email  Age  Experience  \
# 0     Rafe  Talukder  Data Analyst   45000    ra@gmail.com   23           3
# 1   Arefin      Khan       Student   38000  ak@hotmail.com   22           2
# 2   Rezwan     Ahmed     Programer   35000    ra@gmail.com   24           1
# 3    Nayem   Hossain     Developer   75000    nh@gmail.com   28           5
# 4  Al Amin       Mia  Data Analyst   45000    am@gmail.com   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
df.rename(columns={'first':'first_name'},inplace=True)

# %%
df
# Out:
#   first_name      last    profession  Salary           email  Age  Experience  \
# 0       Rafe  Talukder  Data Analyst   45000    ra@gmail.com   23           3
# 1     Arefin      Khan       Student   38000  ak@hotmail.com   22           2
# 2     Rezwan     Ahmed     Programer   35000    ra@gmail.com   24           1
# 3      Nayem   Hossain     Developer   75000    nh@gmail.com   28           5
# 4    Al Amin       Mia  Data Analyst   45000    am@gmail.com   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
df.rename(columns={'last':'last_name'},inplace=True)

# %%
df
# Out:
#   first_name last_name    profession  Salary           email  Age  Experience  \
# 0       Rafe  Talukder  Data Analyst   45000    ra@gmail.com   23           3
# 1     Arefin      Khan       Student   38000  ak@hotmail.com   22           2
# 2     Rezwan     Ahmed     Programer   35000    ra@gmail.com   24           1
# 3      Nayem   Hossain     Developer   75000    nh@gmail.com   28           5
# 4    Al Amin       Mia  Data Analyst   45000    am@gmail.com   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
column_names=['first_name','last_name', 'full_name', 'country_name', 'email']

# %%
df
# Out:
#   first_name last_name    profession  Salary           email  Age  Experience  \
# 0       Rafe  Talukder  Data Analyst   45000    ra@gmail.com   23           3
# 1     Arefin      Khan       Student   38000  ak@hotmail.com   22           2
# 2     Rezwan     Ahmed     Programer   35000    ra@gmail.com   24           1
# 3      Nayem   Hossain     Developer   75000    nh@gmail.com   28           5
# 4    Al Amin       Mia  Data Analyst   45000    am@gmail.com   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
df
# Out:
#   first_name last_name    profession  Salary           email  Age  Experience  \
# 0       Rafe  Talukder  Data Analyst   45000    ra@gmail.com   23           3
# 1     Arefin      Khan       Student   38000  ak@hotmail.com   22           2
# 2     Rezwan     Ahmed     Programer   35000    ra@gmail.com   24           1
# 3      Nayem   Hossain     Developer   75000    nh@gmail.com   28           5
# 4    Al Amin       Mia  Data Analyst   45000    am@gmail.com   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %% [markdown]
# ## Class 02

# %%
import numpy as np
ClassID = np.random.randint(0, 100, 100)
mathematics = np.random.randint(0, 100, 100)
physics = np.random.randint(0, 100, 100)
biology = np.random.randint(0, 100, 100)
chemistry = np.random.randint(0, 100, 100)
higher_math = np.random.randint(0, 100, 100)
ict = np.random.randint(0, 100, 100)

# %%
df1 = pd.DataFrame({
    'ClassID':list(ClassID),
    'math': list(mathematics),
    'phy': list(physics),
    'bio': list(biology),
    'chem':list(chemistry),
    'hmath': list(higher_math),
    'ict': list(ict)
})
df1
# Out:
#     ClassID  math  phy  bio  chem  hmath  ict
# 0        34     2    0   68     3     82   46
# 1        20     6   91   42    40     20   62
# 2        36    87   41   64    43     26   55
# 3        85    71   56   83    89     80    1
# 4        77    35   89   62    50     40   51
# ..      ...   ...  ...  ...   ...    ...  ...
# 95       43    56   72   56    15     37   84
# 96       12    63    7    0    44     48   77
# 97       41    29   54   39    79     82   32
# 98        0    23   66   20    65      4   35
# 99       88    28   59    2    92     52   60
#
# [100 rows x 7 columns]

# %%
#df1.set_index('classID', inplace=True)

# %%
df1
# Out:
#     ClassID  math  phy  bio  chem  hmath  ict
# 0        34     2    0   68     3     82   46
# 1        20     6   91   42    40     20   62
# 2        36    87   41   64    43     26   55
# 3        85    71   56   83    89     80    1
# 4        77    35   89   62    50     40   51
# ..      ...   ...  ...  ...   ...    ...  ...
# 95       43    56   72   56    15     37   84
# 96       12    63    7    0    44     48   77
# 97       41    29   54   39    79     82   32
# 98        0    23   66   20    65      4   35
# 99       88    28   59    2    92     52   60
#
# [100 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
label= list(df1.keys())

# %%
sns.barplot(data=df1)
# Out:
# <AxesSubplot:>

# %%
df1['math'].mean()
# Out:
# 47.97

# %%
df
# Out:
#   first_name last_name    profession  Salary           email  Age  Experience  \
# 0       Rafe  Talukder  Data Analyst   45000    ra@gmail.com   23           3
# 1     Arefin      Khan       Student   38000  ak@hotmail.com   22           2
# 2     Rezwan     Ahmed     Programer   35000    ra@gmail.com   24           1
# 3      Nayem   Hossain     Developer   75000    nh@gmail.com   28           5
# 4    Al Amin       Mia  Data Analyst   45000    am@gmail.com   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
df.set_index('email', inplace=True)

# %%
df.reset_index('email', inplace=True)

# %%
df
# Out:
#             email first_name last_name    profession  Salary  Age  Experience  \
# 0    ra@gmail.com       Rafe  Talukder  Data Analyst   45000   23           3
# 1  ak@hotmail.com     Arefin      Khan       Student   38000   22           2
# 2    ra@gmail.com     Rezwan     Ahmed     Programer   35000   24           1
# 3    nh@gmail.com      Nayem   Hossain     Developer   75000   28           5
# 4    am@gmail.com    Al Amin       Mia  Data Analyst   45000   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
filt= (df['last_name']=='Ahmed') | (df['first_name']=='Rafe')
df.loc[filt, 'email']
# Out:
# 0    ra@gmail.com
# 2    ra@gmail.com
# Name: email, dtype: object

# %%
filt= (df["last_name"]=='Talukder') & (df['first_name']=='Rafe')
df.loc[filt,'email']
# Out:
# 0    ra@gmail.com
# Name: email, dtype: object

# %%
filt= (df['last_name']=='Ahmed') | (df['first_name']=='Rafe')
df.loc[~filt, 'email']
# Out:
# 1    ak@hotmail.com
# 3      nh@gmail.com
# 4      am@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ## Filtaring Data

# %%
filt=(df['last_name']=='Khan')
filt
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: last_name, dtype: bool

# %%
df[filt]
# Out:
#             email first_name last_name profession  Salary  Age  Experience  \
# 1  ak@hotmail.com     Arefin      Khan    Student   38000   22           2
#
#   Gender    full_name country
# 1      M  Arefin Khan   China

# %%
df[df['last_name']=='Khan']
# Out:
#             email first_name last_name profession  Salary  Age  Experience  \
# 1  ak@hotmail.com     Arefin      Khan    Student   38000   22           2
#
#   Gender    full_name country
# 1      M  Arefin Khan   China

# %%
df.loc[filt]
# Out:
#             email first_name last_name profession  Salary  Age  Experience  \
# 1  ak@hotmail.com     Arefin      Khan    Student   38000   22           2
#
#   Gender    full_name country
# 1      M  Arefin Khan   China

# %%
df.loc[filt, 'email']
# Out:
# 1    ak@hotmail.com
# Name: email, dtype: object

# %%
df.loc[filt,'full_name']
# Out:
# 1    Arefin Khan
# Name: full_name, dtype: object

# %%
df1
# Out:
#     ClassID  math  phy  bio  chem  hmath  ict
# 0        34     2    0   68     3     82   46
# 1        20     6   91   42    40     20   62
# 2        36    87   41   64    43     26   55
# 3        85    71   56   83    89     80    1
# 4        77    35   89   62    50     40   51
# ..      ...   ...  ...  ...   ...    ...  ...
# 95       43    56   72   56    15     37   84
# 96       12    63    7    0    44     48   77
# 97       41    29   54   39    79     82   32
# 98        0    23   66   20    65      4   35
# 99       88    28   59    2    92     52   60
#
# [100 rows x 7 columns]

# %%
m_pass=(df1['math']>=33)
m_pass
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
#       ...
# 95     True
# 96     True
# 97    False
# 98    False
# 99    False
# Name: math, Length: 100, dtype: bool

# %%
df1[m_pass]
# Out:
#     ClassID  math  phy  bio  chem  hmath  ict
# 2        36    87   41   64    43     26   55
# 3        85    71   56   83    89     80    1
# 4        77    35   89   62    50     40   51
# 5        66    95   34   66    13     67   45
# 6        81    33   11   68    81     59   48
# ..      ...   ...  ...  ...   ...    ...  ...
# 92       52    98    8   30    35     89   92
# 93       91    74   31   38    75     64   15
# 94       58    93   50   79     7     97   78
# 95       43    56   72   56    15     37   84
# 96       12    63    7    0    44     48   77
#
# [62 rows x 7 columns]

# %%
#df1.loc[m_pass,'First_name']

# %%
# df1.loc[m_pass, ['name', 'ict']]

# %%
m_pass= (df1['math']>33) | (df1['hmath']>33)
m_pass
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
#       ...
# 95     True
# 96     True
# 97     True
# 98    False
# 99     True
# Length: 100, dtype: bool

# %%
df1[m_pass]
# Out:
#     ClassID  math  phy  bio  chem  hmath  ict
# 0        34     2    0   68     3     82   46
# 2        36    87   41   64    43     26   55
# 3        85    71   56   83    89     80    1
# 4        77    35   89   62    50     40   51
# 5        66    95   34   66    13     67   45
# ..      ...   ...  ...  ...   ...    ...  ...
# 94       58    93   50   79     7     97   78
# 95       43    56   72   56    15     37   84
# 96       12    63    7    0    44     48   77
# 97       41    29   54   39    79     82   32
# 99       88    28   59    2    92     52   60
#
# [87 rows x 7 columns]

# %%
df1[m_pass]
# Out:
#     ClassID  math  phy  bio  chem  hmath  ict
# 0        34     2    0   68     3     82   46
# 2        36    87   41   64    43     26   55
# 3        85    71   56   83    89     80    1
# 4        77    35   89   62    50     40   51
# 5        66    95   34   66    13     67   45
# ..      ...   ...  ...  ...   ...    ...  ...
# 94       58    93   50   79     7     97   78
# 95       43    56   72   56    15     37   84
# 96       12    63    7    0    44     48   77
# 97       41    29   54   39    79     82   32
# 99       88    28   59    2    92     52   60
#
# [87 rows x 7 columns]

# %%
#df1.loc[m_pass, ['name', 'chem']

# %%
m_pass=(df1['math']>=33)
m_pass
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
#       ...
# 95     True
# 96     True
# 97    False
# 98    False
# 99    False
# Name: math, Length: 100, dtype: bool

# %% [markdown]
# ### Class 03: Grouping and Aggregating-Analyzing and Exploring Data

# %%
df
# Out:
#             email first_name last_name    profession  Salary  Age  Experience  \
# 0    ra@gmail.com       Rafe  Talukder  Data Analyst   45000   23           3
# 1  ak@hotmail.com     Arefin      Khan       Student   38000   22           2
# 2    ra@gmail.com     Rezwan     Ahmed     Programer   35000   24           1
# 3    nh@gmail.com      Nayem   Hossain     Developer   75000   28           5
# 4    am@gmail.com    Al Amin       Mia  Data Analyst   45000   23           3
#
#   Gender      full_name     country
# 0      M  Rafe Talukder  Bangladesh
# 1      M    Arefin Khan       China
# 2      M   Rezwan Ahmed       India
# 3      M  Nayem Hossain         USA
# 4      F    Al Amin Mia     Germany

# %%
df.describe()
# Out:
#              Salary        Age  Experience
# count      5.000000   5.000000     5.00000
# mean   47600.000000  24.000000     2.80000
# std    15931.101657   2.345208     1.48324
# min    35000.000000  22.000000     1.00000
# 25%    38000.000000  23.000000     2.00000
# 50%    45000.000000  23.000000     3.00000
# 75%    45000.000000  24.000000     3.00000
# max    75000.000000  28.000000     5.00000

# %%
df.count()
# Out:
# email         5
# first_name    5
# last_name     5
# profession    5
# Salary        5
# Age           5
# Experience    5
# Gender        5
# full_name     5
# country       5
# dtype: int64

# %%
df['profession'].value_counts()
# Out:
# Data Analyst    2
# Student         1
# Programer       1
# Developer       1
# Name: profession, dtype: int64

# %%
df.shape
# Out:
# (5, 10)

# %%
df['Experience'].value_counts()
# Out:
# 3    2
# 2    1
# 1    1
# 5    1
# Name: Experience, dtype: int64

# %%
df['jobS']=['Yes','Yes','No','No','Yes']

# %%
df['Country']=['United States', 'Bangladesh', 'India', 'India', 'Canada']

# %%
df
# Out:
#             email first_name last_name    profession  Salary  Age  Experience  \
# 0    ra@gmail.com       Rafe  Talukder  Data Analyst   45000   23           3
# 1  ak@hotmail.com     Arefin      Khan       Student   38000   22           2
# 2    ra@gmail.com     Rezwan     Ahmed     Programer   35000   24           1
# 3    nh@gmail.com      Nayem   Hossain     Developer   75000   28           5
# 4    am@gmail.com    Al Amin       Mia  Data Analyst   45000   23           3
#
#   Gender      full_name     country jobS        Country
# 0      M  Rafe Talukder  Bangladesh  Yes  United States
# 1      M    Arefin Khan       China  Yes     Bangladesh
# 2      M   Rezwan Ahmed       India   No          India
# 3      M  Nayem Hossain         USA   No          India
# 4      F    Al Amin Mia     Germany  Yes         Canada

# %%
df['jobS'].value_counts()
# Out:
# Yes    3
# No     2
# Name: jobS, dtype: int64

# %%
 df['jobS'].value_counts(normalize=True)
# Out:
# Yes    0.6
# No     0.4
# Name: jobS, dtype: float64

# %%
 df['Gender'].value_counts(normalize=True)
# Out:
# M    0.8
# F    0.2
# Name: Gender, dtype: float64

# %% [markdown]
# ### Group By

# %%
Country_g= df.groupby(['Country'])

# %%
Country_g.get_group('India')
# Out:
#           email first_name last_name profession  Salary  Age  Experience  \
# 2  ra@gmail.com     Rezwan     Ahmed  Programer   35000   24           1
# 3  nh@gmail.com      Nayem   Hossain  Developer   75000   28           5
#
#   Gender      full_name country jobS Country
# 2      M   Rezwan Ahmed   India   No   India
# 3      M  Nayem Hossain     USA   No   India

# %%
 Country_g=df.groupby(['Country'])
Country_g["Age"].value_counts()
# Out:
# Country        Age
# Bangladesh     22     1
# Canada         23     1
# India          24     1
#                28     1
# United States  23     1
# Name: Age, dtype: int64

# %%
 Country_grp=df.groupby(['Country'])
Country_grp["jobS"].value_counts()
# Out:
# Country        jobS
# Bangladesh     Yes     1
# Canada         Yes     1
# India          No      2
# United States  Yes     1
# Name: jobS, dtype: int64

# %%
Country_grp= df.groupby(['Country'])
Country_grp["profession"].value_counts()
# Out:
# Country        profession
# Bangladesh     Student         1
# Canada         Data Analyst    1
# India          Developer       1
#                Programer       1
# United States  Data Analyst    1
# Name: profession, dtype: int64

# %%
df.set_index('email', inplace=True)

# %%
df
# Out:
#                first_name last_name    profession  Salary  Age  Experience  \
# email
# ra@gmail.com         Rafe  Talukder  Data Analyst   45000   23           3
# ak@hotmail.com     Arefin      Khan       Student   38000   22           2
# ra@gmail.com       Rezwan     Ahmed     Programer   35000   24           1
# nh@gmail.com        Nayem   Hossain     Developer   75000   28           5
# am@gmail.com      Al Amin       Mia  Data Analyst   45000   23           3
#
#                Gender      full_name     country jobS        Country
# email
# ra@gmail.com        M  Rafe Talukder  Bangladesh  Yes  United States
# ak@hotmail.com      M    Arefin Khan       China  Yes     Bangladesh
# ra@gmail.com        M   Rezwan Ahmed       India   No          India
# nh@gmail.com        M  Nayem Hossain         USA   No          India
# am@gmail.com        F    Al Amin Mia     Germany  Yes         Canada

# %%
df.loc['ak@hotmail.com']
# Out:
# first_name         Arefin
# last_name            Khan
# profession        Student
# Salary              38000
# Age                    22
# Experience              2
# Gender                  M
# full_name     Arefin Khan
# country             China
# jobS                  Yes
# Country        Bangladesh
# Name: ak@hotmail.com, dtype: object

# %%
elook = input ('Enter email:')
df.loc[elook]
# Out:
# Enter email:ak@hotmail.com
# first_name         Arefin
# last_name            Khan
# profession        Student
# Salary              38000
# Age                    22
# Experience              2
# Gender                  M
# full_name     Arefin Khan
# country             China
# jobS                  Yes
# Country        Bangladesh
# Name: ak@hotmail.com, dtype: object

# %%
ilook=input("Enter email id:")
df.loc[ilook]
# Out:
# Enter email id:am@gmail.com
# first_name         Al Amin
# last_name              Mia
# profession    Data Analyst
# Salary               45000
# Age                     23
# Experience               3
# Gender                   F
# full_name      Al Amin Mia
# country            Germany
# jobS                   Yes
# Country             Canada
# Name: am@gmail.com, dtype: object
